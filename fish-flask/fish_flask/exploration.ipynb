# %%
import pandas as pd
from data import position_df, release_tag_df, collection_tag_df

# %%
position_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473952 entries, 0 to 1473951
# Data columns (total 7 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Date_time     1473952 non-null  object
#  1   Tag_code      1473952 non-null  object
#  2   X             1473952 non-null  float64
#  3   Y             1473952 non-null  float64
#  4   Z             1473952 non-null  float64
#  5   MSE           1473952 non-null  float64
#  6   Acoustic Tag  1473952 non-null  object
# dtypes: float64(4), object(3)
# memory usage: 78.7+ MB

# %%
position_df.describe()
# Out:
#                   X             Y             Z           MSE
# count  1.473952e+06  1.473952e+06  1.473952e+06  1.473952e+06
# mean   1.443137e+01  1.572943e+01  3.112256e+01  8.979964e+04
# std    3.123338e+01  3.597048e+01  3.445922e+01  1.373661e+06
# min   -6.000000e+01 -2.500000e+01  0.000000e+00  1.501000e-18
# 25%   -2.131163e+00 -8.818951e+00  2.031891e+00  4.033000e-01
# 50%    8.907724e+00  5.377426e+00  1.903660e+01  1.733000e+00
# 75%    2.920754e+01  3.496294e+01  4.643901e+01  8.761000e+00
# max    1.000000e+02  1.250000e+02  1.148294e+02  1.723000e+08

# %%
position_df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'X'}>,
#         <AxesSubplot: title={'center': 'Y'}>],
#        [<AxesSubplot: title={'center': 'Z'}>,
#         <AxesSubplot: title={'center': 'MSE'}>]], dtype=object)

# %%
release_tag_df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Release Date'}>]], dtype=object)

# %%
collection_tag_df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Detection Time'}>]], dtype=object)
